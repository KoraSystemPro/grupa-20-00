# %%
import pandas as pd

podaci = pd.read_csv("covid-19.csv")
pivot = podaci.pivot_table(index=['Dan', 'Mesec', 'Godina'], columns=['Opis'], aggfunc='sum').fillna(0)

pivot
# Out:
#                                                  Vrednost  \
# Opis             BROJ_HOSPITALIZOVANIH_LICA_ZA_DATI_DATUM
# Dan Mesec Godina
# 1   1     2021                                     8534.0
#           2022                                     2109.0
#     2     2021                                     4034.0
#           2022                                     3848.0
#     3     2021                                     3977.0
# ...                                                   ...
# 31  8     2021                                     1231.0
#     10    2020                                     1122.0
#           2021                                     6764.0
#     12    2020                                     8765.0
#           2021                                     2114.0
#
#                                                          \
# Opis             BROJ_LICA_NA_RESPIRATORU_ZA_DATI_DATUM
# Dan Mesec Godina
# 1   1     2021                                    283.0
# ...
